# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head(100)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# ..  ...       ...                ...        ...                     ...
# 95   54        No      Travel_Rarely       1217  Research & Development
# 96   24        No      Travel_Rarely       1353                   Sales
# 97   28        No         Non-Travel        120                   Sales
# 98   58        No      Travel_Rarely        682                   Sales
# 99   44        No         Non-Travel        489  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df_vis=df[['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']].copy()
df_vis.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
import seaborn as sns
ax=sns.countplot(x="Age", data=df_vis)
print(df_vis['Age'].value_counts())
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="BusinessTravel", data=df_vis)
print(df_vis['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="Attrition", data=df_vis)
print(df_vis['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="DailyRate", data=df_vis)
print(df_vis['DailyRate'].value_counts())
# Out:
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: DailyRate, Length: 886, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="Department", data=df_vis)
print(df_vis['Department'].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="DistanceFromHome", data=df_vis)
print(df_vis['DistanceFromHome'].value_counts())
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="Education", data=df_vis)
print(df_vis['Education'].value_counts())
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="EducationField", data=df_vis)
print(df_vis['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="EnvironmentSatisfaction", data=df_vis)
print(df_vis['EnvironmentSatisfaction'].value_counts())
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="Gender", data=df_vis)
print(df_vis['Gender'].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="HourlyRate", data=df_vis)
print(df_vis['HourlyRate'].value_counts())
# Out:
# 66    29
# 98    28
# 42    28
# 48    28
# 84    28
#       ..
# 31    15
# 53    14
# 68    14
# 38    13
# 34    12
# Name: HourlyRate, Length: 71, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="JobInvolvement", data=df_vis)
print(df_vis['JobInvolvement'].value_counts())
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="JobLevel", data=df_vis)
print(df_vis['JobLevel'].value_counts())
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="JobRole", data=df_vis)
print(df_vis['JobRole'].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="JobSatisfaction", data=df_vis)
print(df_vis['JobSatisfaction'].value_counts())
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="MaritalStatus", data=df_vis)
print(df_vis['MaritalStatus'].value_counts())
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="MonthlyIncome", data=df_vis)
print(df_vis['MonthlyIncome'].value_counts())
# Out:
# 2342     4
# 6142     3
# 2741     3
# 2559     3
# 2610     3
#         ..
# 7104     1
# 2773     1
# 19513    1
# 3447     1
# 4404     1
# Name: MonthlyIncome, Length: 1349, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="OverTime", data=df_vis)
print(df_vis['OverTime'].value_counts())
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="NumCompaniesWorked", data=df_vis)
print(df_vis['NumCompaniesWorked'].value_counts())
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="PercentSalaryHike", data=df_vis)
print(df_vis['PercentSalaryHike'].value_counts())
# Out:
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: PercentSalaryHike, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="PerformanceRating", data=df_vis)
print(df_vis['PerformanceRating'].value_counts())
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="RelationshipSatisfaction", data=df_vis)
print(df_vis['RelationshipSatisfaction'].value_counts())
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="StockOptionLevel", data=df_vis)
print(df_vis['StockOptionLevel'].value_counts())
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="TotalWorkingYears", data=df_vis)
print(df_vis['TotalWorkingYears'].value_counts())
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="TrainingTimesLastYear", data=df_vis)
print(df_vis['TrainingTimesLastYear'].value_counts())
# Out:
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="WorkLifeBalance", data=df_vis)
print(df_vis['WorkLifeBalance'].value_counts())
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="YearsAtCompany", data=df_vis)
print(df_vis['YearsAtCompany'].value_counts())
# Out:
# 5     196
# 1     171
# 3     128
# 2     127
# 10    120
# 4     110
# 7      90
# 9      82
# 8      80
# 6      76
# 0      44
# 11     32
# 20     27
# 13     24
# 15     20
# 14     18
# 22     15
# 12     14
# 21     14
# 18     13
# 16     12
# 19     11
# 17      9
# 24      6
# 33      5
# 25      4
# 26      4
# 31      3
# 32      3
# 27      2
# 36      2
# 29      2
# 23      2
# 37      1
# 40      1
# 34      1
# 30      1
# Name: YearsAtCompany, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="YearsInCurrentRole", data=df_vis)
print(df_vis['YearsInCurrentRole'].value_counts())
# Out:
# 2     372
# 0     244
# 7     222
# 3     135
# 4     104
# 8      89
# 9      67
# 1      57
# 6      37
# 5      36
# 10     29
# 11     22
# 13     14
# 14     11
# 12     10
# 15      8
# 16      7
# 17      4
# 18      2
# Name: YearsInCurrentRole, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="YearsSinceLastPromotion", data=df_vis)
print(df_vis['YearsSinceLastPromotion'].value_counts())
# Out:
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: YearsSinceLastPromotion, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="YearsWithCurrManager", data=df_vis)
print(df_vis['YearsWithCurrManager'].value_counts())
# Out:
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: YearsWithCurrManager, dtype: int64

# %%
df.drop(labels=['BusinessTravel', 'Department', 'EducationField','Gender','MaritalStatus','Over18', 'EmployeeCount','StandardHours'], axis=1)
# Out:
#       Age Attrition  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0      41       Yes       1102                 1          2               1
# 1      49        No        279                 8          1               2
# 2      37       Yes       1373                 2          2               4
# 3      33        No       1392                 3          4               5
# 4      27        No        591                 2          1               7
# ...   ...       ...        ...               ...        ...             ...
# 1465   36        No        884                23          2            2061
# 1466   39        No        613                 6          1            2062
# 1467   27        No        155                 4          3            2064
# 1468   49        No       1023                 2          3            2065
# 1469   34        No        628                 8          3            2068
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(10, 4))
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap ='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('darkgrid')
sns.countplot(x ='Attrition', data = df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
plt.figure(figsize =(10, 6))
sns.boxplot(y ='MonthlyIncome', x ='Attrition', data = df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='MonthlyIncome'>

# %%
df.drop('EmployeeCount', axis = 1, inplace = True)
df.drop('StandardHours', axis = 1, inplace = True)
df.drop('EmployeeNumber', axis = 1, inplace = True)
df.drop('Over18', axis = 1, inplace = True)
print(df.shape)
# Out:
# (1470, 31)

# %%
y = df.iloc[:, 1]
X = df
X.drop('Attrition', axis = 1, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
y = lb.fit_transform(y)

# %%
dum_BusinessTravel = pd.get_dummies(df['BusinessTravel'],
                                    prefix ='BusinessTravel')
dum_Department = pd.get_dummies(df['Department'],
                                prefix ='Department')
dum_EducationField = pd.get_dummies(df['EducationField'],
                                    prefix ='EducationField')
dum_Gender = pd.get_dummies(df['Gender'],
                            prefix ='Gender', drop_first = True)
dum_JobRole = pd.get_dummies(df['JobRole'],
                             prefix ='JobRole')
dum_MaritalStatus = pd.get_dummies(df['MaritalStatus'],
                                   prefix ='MaritalStatus')
dum_OverTime = pd.get_dummies(df['OverTime'],
                              prefix ='OverTime', drop_first = True)
X = pd.concat([X, dum_BusinessTravel, dum_Department,
               dum_EducationField, dum_Gender, dum_JobRole,
               dum_MaritalStatus, dum_OverTime], axis = 1)
X.drop(['BusinessTravel', 'Department', 'EducationField',
        'Gender', 'JobRole', 'MaritalStatus', 'OverTime'],
        axis = 1, inplace = True)
 
print(X.shape)
# Out:
# (1470, 49)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.25, random_state = 40)

# %%
from sklearn.neighbors import KNeighborsClassifier
neighbors = []
cv_scores = []
for k in range(1, 40, 2):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    scores = cross_val_score(knn, X_train, y_train, cv = 10, scoring = 'accuracy')
    cv_scores.append(scores.mean())
error_rate = [1-x for x in cv_scores]
optimal_k = neighbors[error_rate.index(min(error_rate))]
print('The optimal number of neighbors is % d ' % optimal_k)
plt.figure(figsize = (10, 6))
plt.plot(range(1, 40, 2), error_rate, color ='blue', linestyle ='dashed', marker ='o',
         markerfacecolor ='red', markersize = 10)
plt.xlabel('Number of neighbors')
plt.ylabel('Error')
plt.show()
# Out:
# The optimal number of neighbors is  7

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
 
def print_score(clf, X_train, y_train, X_test, y_test, train = True):
    if train:
        print("Train Result:")
        print("Classification Report: \n {}\n".format(classification_report(
                y_train, clf.predict(X_train))))
        print("Confusion Matrix: \n {}\n".format(confusion_matrix(
                y_train, clf.predict(X_train))))
 
        res = cross_val_score(clf, X_train, y_train,
                              cv = 10, scoring ='accuracy')
        print("Average Accuracy: \t {0:.4f}".format(np.mean(res)))
        print("Accuracy SD: \t\t {0:.4f}".format(np.std(res)))
        print("accuracy score: {0:.4f}\n".format(accuracy_score(
                y_train, clf.predict(X_train))))
    elif train == False:
        print("Test Result:")
        print("-----------")
        print("Classification Report: \n {}\n".format(
                classification_report(y_test, clf.predict(X_test))))
        print("Confusion Matrix: \n {}\n".format(
                confusion_matrix(y_test, clf.predict(X_test))))
        print("accuracy score: {0:.4f}\n".format(
                accuracy_score(y_test, clf.predict(X_test))))
knn = KNeighborsClassifier(n_neighbors = 7)
knn.fit(X_train, y_train)
print_score(knn, X_train, y_train, X_test, y_test, train = True)
print_score(knn, X_train, y_train, X_test, y_test, train = False)
# Out:
# Train Result:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       922
#            1       0.83      0.19      0.32       180
#
#     accuracy                           0.86      1102
#    macro avg       0.85      0.59      0.62      1102
# weighted avg       0.86      0.86      0.82      1102
#
#
# Confusion Matrix:
#  [[915   7]
#  [145  35]]
#
# Average Accuracy: 	 0.8421
# Accuracy SD: 		 0.0148
# accuracy score: 0.8621
#
# Test Result:
# -----------
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90       311
#            1       0.14      0.04      0.06        57
#
#     accuracy                           0.82       368
#    macro avg       0.49      0.50      0.48       368
# weighted avg       0.74      0.82      0.77       368
#
#
# Confusion Matrix:
#  [[299  12]
#  [ 55   2]]
#
# accuracy score: 0.8179
